# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql sqlite:///TMDB.db
# Out:
# 'Connected: @TMDB.db'

# %% [markdown]
# ### Question 4
#
# How many movies are there that contain the word “Spider” within their title?

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     movies
# WHERE
#     title LIKE '%Spider%';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(557, 'Spider-Man', '2002-05-01 00:00:00.000000', 139000000, 'http://www.sonypictures.com/movies/spider-man/', 'en', 'Spider-Man', 'After being bitten by a genetically altered spider, nerdy high school student Peter Parker is endowed with amazing powers.', 82.502566, 821708551.0, 121.0, 'Released', 'With great power comes great responsibility.', 6.8, 5265),
#  (558, 'Spider-Man 2', '2004-06-25 00:00:00.000000', 200000000, 'http://www.sonypictures.com/movies/spider-man2/', 'en', 'Spider-Man 2', "Peter Parker is going through a major identity crisis. Burned out from being Spider-Man, he decides to shelve his superhero alter ego, which leaves t ... (30 characters truncated) ... of carnage left by the evil Doc Ock. In the meantime, Parker still can't act on his feelings for Mary Jane Watson, a girl he's loved since childhood.", 35.149586, 783766341.0, 127.0, 'Released', "There's a hero in all of us.", 6.7, 4321),
#  (559, 'Spider-Man 3', '2007-05-01 00:00:00.000000', 258000000, 'http://www.sonypictures.com/movies/spider-man3/', 'en', 'Spider-Man 3', 'The seemingly invincible Spider-Man goes up against an all-new crop of villain û including the shape-shifting Sandman. While Spider-ManÆs superpowers are altered by an alien organism, his alter ego, Peter Parker, deals with nemesis Eddie Brock and also gets caught up in a love triangle.', 115.699814, 890871626.0, 139.0, 'Released', 'The battle within.', 5.9, 3576),
#  (1930, 'The Amazing Spider-Man', '2012-06-27 00:00:00.000000', 215000000, 'http://www.theamazingspiderman.com', 'en', 'The Amazing Spider-Man', "Peter Parker is an outcast high schooler abandoned by his parents as a boy, leaving him to be raised by his Uncle Ben and Aunt May. Like most teenage ... (340 characters truncated) ... collision course with Connors' alter ego, The Lizard, Peter will make life-altering choices to use his powers and shape his destiny to become a hero.", 89.866276, 752215857.0, 136.0, 'Released', 'The untold story begins.', 6.5, 6586),
#  (2043, 'Along Came a Spider', '2001-04-06 00:00:00.000000', 60000000, None, 'en', 'Along Came a Spider', 'When a teacher kidnaps a girl from a prestigious school, homicide detective, Alex Cross takes the case and teams up with young security agent, Jezzie ... (53 characters truncated) ... he brutal psychopath. Every second counts as Alex and Jezzie attempt to track down the kidnapper before the spider claims another victim for its web.', 21.252797, 105178561.0, 104.0, 'Released', 'The game is far from over.', 6.1, 400),
#  (8204, 'The Spiderwick Chronicles', '2008-02-14 00:00:00.000000', 90000000, None, 'en', 'The Spiderwick Chronicles', 'Upon moving into the run-down Spiderwick Estate with their mother, twin brothers Jared and Simon Grace, along with their sister Mallory, find themselves pulled into an alternate world full of faeries and other creatures.', 21.436682, 162839667.0, 95.0, 'Released', 'Their World Is Closer Than You Think.', 6.3, 572),
#  (9613, 'Spider', '2002-12-13 00:00:00.000000', 0, 'http://www.spiderthemovie.com/', 'en', 'Spider', 'A mentally disturbed man takes residence in a halfway house. His mind gradually slips back into the realm created by his illness, where he replays a key part of his childhood.', 6.948401, 0.0, 98.0, 'Released', 'The only thing worse than losing your mind... is finding it again.', 6.4, 168),
#  (30315, 'Kingdom of the Spiders', '1977-08-24 00:00:00.000000', 500000, None, 'en', 'Kingdom of the Spiders', 'Investigating the mysterious deaths of a number of farm animals, vet Rack Hansen discovers that his town lies in the path of hoards of migrating tarantulas. Before he can take action, the streets are overrun by killer spiders, trapping a small group of towns folk in a remote hotel.', 2.537032, 17000000.0, 97.0, 'Released', 'A Living, Crawling, Hell on Earth!', 5.7, 30),
#  (102382, 'The Amazing Spider-Man 2', '2014-04-16 00:00:00.000000', 200000000, 'http://www.theamazingspiderman.com', 'en', 'The Amazing Spider-Man 2', 'For Peter Parker, life is busy. Between taking out the bad guys as Spider-Man and spending time with the person he loves, Gwen Stacy, high school gra ... (173 characters truncated) ... Things will change for Peter when a new villain, Electro, emerges, an old friend, Harry Osborn, returns, and Peter uncovers new clues about his past.', 89.270217, 705717432.0, 142.0, 'Released', 'No more secrets.', 6.5, 4179)]
